# %% [markdown]
# # Importing Open AI API

# %%
import os
from dotenv import load_dotenv
import openai

# %%
# Retrieving the openaiapikey
load_dotenv()
openai_api_key = os.getenv("openai_api_key")

# Initialize the OpenAI API client
openai.api_key = openai_api_key

# %%
# # Prompt for the AI model
# prompt = "Translate the following English text to Spanish: 'Hello, how are you my beautiful Jeremie?'"

<<<<<<< local
# Make a request to the API to generate text
response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages = [{"role": "user", "content": prompt}],
    max_tokens = 20
)
=======
# # Make a request to the API to generate text
# response = openai.chat.completions.create(
#     model="gpt-4.1-nano",
#     messages = [{"role": "user", "content": prompt}],
#     max_tokens = 20
# )
# response.choices[0].message.content
>>>>>>> remote

# %%
# Out:
# <<<<<<< local
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response.choices[0].message.content
#
# NameError: name 'response' is not defined
# >>>>>>> remote
# <<<<<<< local <modified: text/plain>
# 'Hola, ¿cómo estás, mi hermoso Jeremie?'
# ...
# >>>>>>> remote <removed>

# %% [markdown]
# # INPUT - Integrating Customer Details

# %% [markdown]
# # OUTPUT - Personalized script (FR and EN)
