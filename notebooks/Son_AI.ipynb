# %% [markdown]
# # Importing Open AI API

# %% [markdown]
# Dataset: https://archive.ics.uci.edu/dataset/222/bank+marketing

# %%
import os
from dotenv import load_dotenv
import openai

# %%
# Retrieving the openaiapikey
load_dotenv()
openai_api_key = os.getenv("openai_api_key")

# Initialize the OpenAI API client
openai.api_key = openai_api_key

# %%
# # Prompt for the AI model
# prompt = "Translate the following English text to Spanish: 'Hello, how are you my beautiful Jeremie?'"

# # Make a request to the API to generate text
# response = openai.chat.completions.create(
#     model="gpt-4.1-nano",
#     messages = [{"role": "user", "content": prompt}],
#     max_tokens = 20
# )
# response.choices[0].message.content

# %% [markdown]
# # INPUT and OUTPUT - Integrating Customer Details

# %%
#objective is to bring in data from df and use it as input for chatgpt
import sys
sys.path.append('/home/tsonm/code/tsonma/lewagon_cust_targeting')
from src.getdata_utils import load_data

X, _ = load_data()

X.head(5)
#output would be a brief text that is more personalized for the customer
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  campaign  pdays  previous poutcome
# 0  unknown    5   may         1     -1         0  unknown
# 1  unknown    5   may         1     -1         0  unknown
# 2  unknown    5   may         1     -1         0  unknown
# 3  unknown    5   may         1     -1         0  unknown
# 4  unknown    5   may         1     -1         0  unknown

# %%
import pandas as pd
import openai

# Example DataFrame
df = X.head(3)
# Convert DataFrame to string (CSV format)
df_str = df.to_csv(index=False)

# Define system prompt (sets the agent's persona)
system_prompt = """
You are a highly experienced and successful bank representative,
specialized in investments, with a proven track record of helping clients achieve
their financial goals while always acting in their best interest.
You are empathetic, trustworthy, and persuasive in your communication.
"""

# Define user prompt (task instruction)
user_prompt = f"""
Here is the customer data:
{df_str}

Please generate a personalized call script for each customer based on the data provided with a dash of humor
"""

# API request
response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    max_tokens=300
)

# Output
print(response.choices[0].message.content)
# Out:
# Certainly! Here are personalized call scripts for each customer, tailored to their data and with a touch of humor to make the conversation engaging:
#
# ---
#
# ### Customer 1: Age 58, Management, Married
# **Script:**
#
# "Good morning! This is [Your Name] from [Bank Name], and I hope you're having a fantastic day. I was looking at your profile and noticed you're a seasoned management professional — clearly, you've already mastered the art of managing life! Like fine wine, your financial strategy has only gotten better with age.
#
# I wanted to chat about some investment opportunities that could add more sparkle to your financial glass. Would now be a good time, or shall I call back when you're feeling as relaxed as a vacation in the Bahamas?"
#
# *If yes:*
# "Great! With your experience and proven stability, we have some tailored options that could help grow your wealth further — no gimmicks, just genuine opportunities. Think of it as a financial spa session for your assets!"
#
# ...

# %% [markdown]
# # Integrating ChatGPT to Streamlit
